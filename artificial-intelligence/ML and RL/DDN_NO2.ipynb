# %% [markdown]
# # Machine Learning, DNN for regression
#
# ### Description of the dataset NO2
# The dataset that we are going to use for this lesson was obtained from the StatLib repository. http://lib.stat.cmu.edu/datasets/ (NO2).
# The data are a subsample of 500 observations from a data set that originate in a study where air pollution at a road is related to traffic volume and meteorological variables, collected by the Norwegian Public Roads Administration. The response variable (column 1) consist of hourly values of the logarithm of the concentration of NO2 (particles), measured at Alnabru in Oslo, Norway, between October 2001 and August 2003. The predictor variables (columns 2 to 8) are the logarithm of the number of cars per hour, temperature $2$ meters above ground (degree C), wind speed (meters/second), the temperature difference between $25$ and $2$ meters above ground (degree C), wind direction (degrees between 0 and 360), hour of day and day number from October 1 2001. Submitted by Magne Aldrin (magne.aldrin@nr.no). [28/Jul/04] (19kbytes)
#
#
# Target variable:
# - NO2 concentration (log) [lno2]
#
# Features:
# - log of car per hour [lc]
#
# - temperature 2 meters above the ground (degree C)[t2]
#
# - wind speed (meters/seconds) [ws]
#
# - temperature difference between 25 meters and 2 meters above the ground (degree C) [td25]
#
# - wind direction (degrees between 0 and 360) [wd]
#
# - hour of day [hd] average house occupancy
#
# - day number from Oct. 1 2001 [dn]

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from math import sqrt
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics

# %% [markdown]
# ### ASSIGNING LABELS TO FEATURES
# We assign the labels to the corresponding columns to have a clean representation of the dataset

# %%
features = ['lc', 't2', 'ws', 'td25', 'wd', 'hd', 'dn']

# %% [markdown]
# ### CREATE THE DNN LARGE NETWORK MODEL
#
#
# <img src="images/DNN-all.png" alt="DNN Model Large" width="500"/>
#
#
# #### Create the network as indicated in the image above. All activation functions should be ReLU. Have a look at the slide for hints on the code to use.

# %%
def create_model_large():
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(40, activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    return model

# %% [markdown]
# ### CREATE THE TINY ANN MODEL
#
# #### Create an ANN with 1 layer containing 3 neurons (model tiny), alla activation functions should be ReLU.

# %%
def create_model_tiny():
    # create model
    model = Sequential()
    model.add(Dense(3, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    return model

# %% [markdown]
# ### CREATE THE SMALL ANN MODEL
#
# #### Create an ANN with 1 layer containing 10 neurons (model small), alla activation functions should be ReLU.

# %%
def create_model_small():
    # create model
    model = Sequential()
    #your code here	
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    return model

# %% [markdown]
# ### CREATE THE MEDIUM DNN MODEL
#
# #### Create an DNN with 2 layers containing respectively 10 and 30 neurons (model medium), alla activation functions should be ReLU.

# %%
def create_model_medium():
    # create model
    model = Sequential()    
    #your code here	
    model.add(Dense(10, input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(30, activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    return model

# %%
def create_model_quiz():
    model = Sequential()
    model.add(Dense(64,input_dim=X_train.shape[1], activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(64, activation='relu'))
    model.add(Dense(1))
    # Compile model
    model.compile(optimizer ='adam', loss = 'mean_squared_error', metrics =[metrics.mae])
    return model

# %% [markdown]
# ### Evaluating the model
#
# The following functions computes the Root Mean Squared Error and the Normalized Root Mean Squared Error between the groud thruth (real) and inferred (pred) responses.

# %%
def RMSE(real, pred):
    return sqrt(mean_squared_error(real, pred))

def NRMSE(real, pred):
    return sqrt(mean_squared_error(real, pred)/(real.max() - real.min()))

# %% [markdown]
# ### Loading  the data
#
# #### Using the panda library to load data, provide a descriptive summary

# %%
# Load data
df = pd.read_csv('NO2.csv', index_col=False)

# Descriptive statistics summary
df.describe()
# Out:
#              lno2          lc          t2          ws        td25          wd  \
# count  500.000000  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     3.698368    6.973342    0.847400    3.056000    0.149400  143.370400
# std      0.750597    1.087166    6.524636    1.784172    1.065237   86.510213
# min      1.223780    4.127130  -18.600000    0.300000   -5.400000    2.000000
# 25%      3.213862    6.175842   -3.900000    1.675000   -0.200000   72.000000
# 50%      3.848020    7.425360    1.100000    2.800000    0.000000   97.000000
# 75%      4.216930    7.793175    4.900000    4.200000    0.600000  220.000000
# max      6.395090    8.348540   21.100000    9.900000    4.300000  359.000000
#
#                hd          dn
# count  500.000000  500.000000
# mean    12.382000  310.474000
# std      6.802693  200.977754
# min      1.000000   32.000000
# 25%      6.000000  118.750000
# 50%     12.500000  212.000000
# 75%     18.000000  513.000000
# max     24.000000  608.000000

# %% [markdown]
# ### Visualzing the relationships among the features in the data
#
# #### Compute and visualize a correlation matring among the features (using the seaborn library).

# %%
# Correlation matrix
corrmat = df.corr()

# Generate a mask for the upper triangle
matrix = np.triu(corrmat)
f, ax = plt.subplots(figsize=(12, 9))
sns.set(font_scale=1)
sns.heatmap(corrmat, vmin=-1, vmax=1, center= 0, square=True, annot=True, annot_kws={'size': 8}, mask=matrix, fmt='.2g', cmap= 'coolwarm')

plt.show()

# %% [markdown]
# ### Standizing the data
#
# #### Standardize features to have 0 mean, sigma 1 and range between -1 and 1.  Do not standardize the response.

# %%
# Standardizing data
sc= MinMaxScaler(feature_range=(-1,1))

for var in features:
    if(var != 'lno2'):
        df[var] = sc.fit_transform(df[var].values.reshape(-1, 1))

# %% [markdown]
# ### Preparing the data for training, using validation set approach
#
# #### Remove labels and create the validation set.

# %%
#NumPy representation of the data frame (removing labels)
df = df.to_numpy() #df=df.values

#divide predictors from features
X = df[:, 1:]
y = df[:, 0]

seed = 7
np.random.seed(seed)

# split dataset in 75% for traininig and 25% for testing (500 -> 375,125)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=seed)

# split training in 70% for traininig and 30% for validating (375 -> 300,75)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.30)

# Model creation (choose between tiny, small, medium and large by using the appropriate function)
model = create_model_quiz()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                512
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dense_3 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 8,897
# Trainable params: 8,897
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Fit the DNN to the data

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150, batch_size=32)
# Out:
# Epoch 1/150
# 9/9 [==============================] - 2s 65ms/step - loss: 13.7281 - mean_absolute_error: 3.6252 - val_loss: 12.0826 - val_mean_absolute_error: 3.3972
# Epoch 2/150
# 9/9 [==============================] - 0s 11ms/step - loss: 10.9667 - mean_absolute_error: 3.2260 - val_loss: 8.9937 - val_mean_absolute_error: 2.9078
# Epoch 3/150
# 9/9 [==============================] - 0s 11ms/step - loss: 7.4464 - mean_absolute_error: 2.6157 - val_loss: 4.8326 - val_mean_absolute_error: 2.0889
# Epoch 4/150
# 9/9 [==============================] - 0s 10ms/step - loss: 3.1326 - mean_absolute_error: 1.6039 - val_loss: 1.0855 - val_mean_absolute_error: 0.9013
# Epoch 5/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.7868 - mean_absolute_error: 0.7145 - val_loss: 0.9165 - val_mean_absolute_error: 0.7204
# Epoch 6/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.8482 - mean_absolute_error: 0.7357 - val_loss: 0.4415 - val_mean_absolute_error: 0.4885
# Epoch 7/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.4477 - mean_absolute_error: 0.5273 - val_loss: 0.4370 - val_mean_absolute_error: 0.5408
# Epoch 8/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.4621 - mean_absolute_error: 0.5465 - val_loss: 0.3886 - val_mean_absolute_error: 0.4995
# Epoch 9/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3725 - mean_absolute_error: 0.4792 - val_loss: 0.3373 - val_mean_absolute_error: 0.4456
# Epoch 10/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.3676 - mean_absolute_error: 0.4791 - val_loss: 0.3485 - val_mean_absolute_error: 0.4564
# Epoch 11/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3493 - mean_absolute_error: 0.4648 - val_loss: 0.3420 - val_mean_absolute_error: 0.4465
# Epoch 12/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.3353 - mean_absolute_error: 0.4556 - val_loss: 0.3572 - val_mean_absolute_error: 0.4608
# Epoch 13/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3246 - mean_absolute_error: 0.4498 - val_loss: 0.3401 - val_mean_absolute_error: 0.4474
# Epoch 14/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.3188 - mean_absolute_error: 0.4455 - val_loss: 0.3413 - val_mean_absolute_error: 0.4531
# Epoch 15/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.3105 - mean_absolute_error: 0.4394 - val_loss: 0.3451 - val_mean_absolute_error: 0.4543
# Epoch 16/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3097 - mean_absolute_error: 0.4380 - val_loss: 0.3430 - val_mean_absolute_error: 0.4550
# Epoch 17/150
# 9/9 [==============================] - 0s 17ms/step - loss: 0.3049 - mean_absolute_error: 0.4334 - val_loss: 0.3402 - val_mean_absolute_error: 0.4539
# Epoch 18/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.3014 - mean_absolute_error: 0.4319 - val_loss: 0.3421 - val_mean_absolute_error: 0.4557
# Epoch 19/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2952 - mean_absolute_error: 0.4300 - val_loss: 0.3377 - val_mean_absolute_error: 0.4529
# Epoch 20/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2938 - mean_absolute_error: 0.4303 - val_loss: 0.3310 - val_mean_absolute_error: 0.4479
# Epoch 21/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2906 - mean_absolute_error: 0.4277 - val_loss: 0.3316 - val_mean_absolute_error: 0.4482
# Epoch 22/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2881 - mean_absolute_error: 0.4250 - val_loss: 0.3349 - val_mean_absolute_error: 0.4478
# Epoch 23/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2840 - mean_absolute_error: 0.4213 - val_loss: 0.3325 - val_mean_absolute_error: 0.4472
# Epoch 24/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2820 - mean_absolute_error: 0.4195 - val_loss: 0.3319 - val_mean_absolute_error: 0.4447
# Epoch 25/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2791 - mean_absolute_error: 0.4165 - val_loss: 0.3286 - val_mean_absolute_error: 0.4458
# Epoch 26/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2816 - mean_absolute_error: 0.4184 - val_loss: 0.3288 - val_mean_absolute_error: 0.4455
# Epoch 27/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2796 - mean_absolute_error: 0.4188 - val_loss: 0.3305 - val_mean_absolute_error: 0.4491
# Epoch 28/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2719 - mean_absolute_error: 0.4119 - val_loss: 0.3177 - val_mean_absolute_error: 0.4438
# Epoch 29/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2681 - mean_absolute_error: 0.4112 - val_loss: 0.3299 - val_mean_absolute_error: 0.4493
# Epoch 30/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2763 - mean_absolute_error: 0.4184 - val_loss: 0.3382 - val_mean_absolute_error: 0.4566
# Epoch 31/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2669 - mean_absolute_error: 0.4135 - val_loss: 0.3307 - val_mean_absolute_error: 0.4559
# Epoch 32/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2635 - mean_absolute_error: 0.4090 - val_loss: 0.3356 - val_mean_absolute_error: 0.4498
# Epoch 33/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2599 - mean_absolute_error: 0.4030 - val_loss: 0.3267 - val_mean_absolute_error: 0.4443
# Epoch 34/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2572 - mean_absolute_error: 0.3995 - val_loss: 0.3234 - val_mean_absolute_error: 0.4406
# Epoch 35/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2578 - mean_absolute_error: 0.4019 - val_loss: 0.3177 - val_mean_absolute_error: 0.4378
# Epoch 36/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2517 - mean_absolute_error: 0.3967 - val_loss: 0.3092 - val_mean_absolute_error: 0.4325
# Epoch 37/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2590 - mean_absolute_error: 0.3993 - val_loss: 0.3173 - val_mean_absolute_error: 0.4363
# Epoch 38/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2469 - mean_absolute_error: 0.3937 - val_loss: 0.3182 - val_mean_absolute_error: 0.4379
# Epoch 39/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2503 - mean_absolute_error: 0.3995 - val_loss: 0.3187 - val_mean_absolute_error: 0.4408
# Epoch 40/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2457 - mean_absolute_error: 0.3952 - val_loss: 0.3155 - val_mean_absolute_error: 0.4403
# Epoch 41/150
# 9/9 [==============================] - 0s 7ms/step - loss: 0.2429 - mean_absolute_error: 0.3903 - val_loss: 0.3105 - val_mean_absolute_error: 0.4328
# Epoch 42/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2425 - mean_absolute_error: 0.3907 - val_loss: 0.3073 - val_mean_absolute_error: 0.4353
# Epoch 43/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2373 - mean_absolute_error: 0.3873 - val_loss: 0.3164 - val_mean_absolute_error: 0.4356
# Epoch 44/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2434 - mean_absolute_error: 0.3948 - val_loss: 0.3200 - val_mean_absolute_error: 0.4414
# Epoch 45/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2352 - mean_absolute_error: 0.3856 - val_loss: 0.3190 - val_mean_absolute_error: 0.4419
# Epoch 46/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2310 - mean_absolute_error: 0.3816 - val_loss: 0.3179 - val_mean_absolute_error: 0.4391
# Epoch 47/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2336 - mean_absolute_error: 0.3839 - val_loss: 0.3150 - val_mean_absolute_error: 0.4400
# Epoch 48/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2291 - mean_absolute_error: 0.3800 - val_loss: 0.3166 - val_mean_absolute_error: 0.4409
# Epoch 49/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2325 - mean_absolute_error: 0.3859 - val_loss: 0.3178 - val_mean_absolute_error: 0.4392
# Epoch 50/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2279 - mean_absolute_error: 0.3804 - val_loss: 0.3064 - val_mean_absolute_error: 0.4404
# Epoch 51/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2249 - mean_absolute_error: 0.3775 - val_loss: 0.3066 - val_mean_absolute_error: 0.4343
# Epoch 52/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2233 - mean_absolute_error: 0.3756 - val_loss: 0.3109 - val_mean_absolute_error: 0.4325
# Epoch 53/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2264 - mean_absolute_error: 0.3784 - val_loss: 0.3096 - val_mean_absolute_error: 0.4378
# Epoch 54/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2178 - mean_absolute_error: 0.3724 - val_loss: 0.3101 - val_mean_absolute_error: 0.4378
# Epoch 55/150
# 9/9 [==============================] - 0s 8ms/step - loss: 0.2187 - mean_absolute_error: 0.3712 - val_loss: 0.3093 - val_mean_absolute_error: 0.4387
# Epoch 56/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2130 - mean_absolute_error: 0.3689 - val_loss: 0.3124 - val_mean_absolute_error: 0.4410
# Epoch 57/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2157 - mean_absolute_error: 0.3670 - val_loss: 0.3085 - val_mean_absolute_error: 0.4404
# Epoch 58/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.2111 - mean_absolute_error: 0.3642 - val_loss: 0.3137 - val_mean_absolute_error: 0.4397
# Epoch 59/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2092 - mean_absolute_error: 0.3641 - val_loss: 0.3069 - val_mean_absolute_error: 0.4371
# Epoch 60/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2093 - mean_absolute_error: 0.3627 - val_loss: 0.3034 - val_mean_absolute_error: 0.4339
# Epoch 61/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2088 - mean_absolute_error: 0.3604 - val_loss: 0.2978 - val_mean_absolute_error: 0.4349
# Epoch 62/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2092 - mean_absolute_error: 0.3657 - val_loss: 0.2997 - val_mean_absolute_error: 0.4354
# Epoch 63/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2195 - mean_absolute_error: 0.3687 - val_loss: 0.2983 - val_mean_absolute_error: 0.4359
# Epoch 64/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2037 - mean_absolute_error: 0.3582 - val_loss: 0.2986 - val_mean_absolute_error: 0.4352
# Epoch 65/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2002 - mean_absolute_error: 0.3548 - val_loss: 0.3047 - val_mean_absolute_error: 0.4328
# Epoch 66/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.2035 - mean_absolute_error: 0.3563 - val_loss: 0.3031 - val_mean_absolute_error: 0.4313
# Epoch 67/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.2002 - mean_absolute_error: 0.3534 - val_loss: 0.3085 - val_mean_absolute_error: 0.4349
# Epoch 68/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.2052 - mean_absolute_error: 0.3594 - val_loss: 0.3029 - val_mean_absolute_error: 0.4335
# Epoch 69/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.2006 - mean_absolute_error: 0.3543 - val_loss: 0.3024 - val_mean_absolute_error: 0.4351
# Epoch 70/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1915 - mean_absolute_error: 0.3469 - val_loss: 0.3019 - val_mean_absolute_error: 0.4350
# Epoch 71/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1902 - mean_absolute_error: 0.3458 - val_loss: 0.2969 - val_mean_absolute_error: 0.4336
# Epoch 72/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1946 - mean_absolute_error: 0.3509 - val_loss: 0.2932 - val_mean_absolute_error: 0.4400
# Epoch 73/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.2016 - mean_absolute_error: 0.3578 - val_loss: 0.2895 - val_mean_absolute_error: 0.4347
# Epoch 74/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1884 - mean_absolute_error: 0.3469 - val_loss: 0.3054 - val_mean_absolute_error: 0.4353
# Epoch 75/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1891 - mean_absolute_error: 0.3445 - val_loss: 0.3090 - val_mean_absolute_error: 0.4341
# Epoch 76/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1892 - mean_absolute_error: 0.3449 - val_loss: 0.2959 - val_mean_absolute_error: 0.4384
# Epoch 77/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1945 - mean_absolute_error: 0.3472 - val_loss: 0.2915 - val_mean_absolute_error: 0.4338
# Epoch 78/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1854 - mean_absolute_error: 0.3412 - val_loss: 0.2965 - val_mean_absolute_error: 0.4371
# Epoch 79/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1965 - mean_absolute_error: 0.3500 - val_loss: 0.3056 - val_mean_absolute_error: 0.4377
# Epoch 80/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1810 - mean_absolute_error: 0.3362 - val_loss: 0.2918 - val_mean_absolute_error: 0.4307
# Epoch 81/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1749 - mean_absolute_error: 0.3318 - val_loss: 0.2917 - val_mean_absolute_error: 0.4291
# Epoch 82/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1749 - mean_absolute_error: 0.3307 - val_loss: 0.2914 - val_mean_absolute_error: 0.4300
# Epoch 83/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1720 - mean_absolute_error: 0.3290 - val_loss: 0.2902 - val_mean_absolute_error: 0.4318
# Epoch 84/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1737 - mean_absolute_error: 0.3317 - val_loss: 0.2838 - val_mean_absolute_error: 0.4277
# Epoch 85/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1702 - mean_absolute_error: 0.3267 - val_loss: 0.2855 - val_mean_absolute_error: 0.4259
# Epoch 86/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1681 - mean_absolute_error: 0.3246 - val_loss: 0.2923 - val_mean_absolute_error: 0.4271
# Epoch 87/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1679 - mean_absolute_error: 0.3244 - val_loss: 0.2929 - val_mean_absolute_error: 0.4283
# Epoch 88/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1648 - mean_absolute_error: 0.3230 - val_loss: 0.2904 - val_mean_absolute_error: 0.4316
# Epoch 89/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1629 - mean_absolute_error: 0.3186 - val_loss: 0.2888 - val_mean_absolute_error: 0.4312
# Epoch 90/150
# 9/9 [==============================] - 0s 9ms/step - loss: 0.1623 - mean_absolute_error: 0.3208 - val_loss: 0.2893 - val_mean_absolute_error: 0.4310
# Epoch 91/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1628 - mean_absolute_error: 0.3200 - val_loss: 0.2851 - val_mean_absolute_error: 0.4328
# Epoch 92/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1613 - mean_absolute_error: 0.3219 - val_loss: 0.2916 - val_mean_absolute_error: 0.4341
# Epoch 93/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1634 - mean_absolute_error: 0.3192 - val_loss: 0.2882 - val_mean_absolute_error: 0.4300
# Epoch 94/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1549 - mean_absolute_error: 0.3126 - val_loss: 0.2864 - val_mean_absolute_error: 0.4264
# Epoch 95/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1534 - mean_absolute_error: 0.3112 - val_loss: 0.2837 - val_mean_absolute_error: 0.4267
# Epoch 96/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1511 - mean_absolute_error: 0.3100 - val_loss: 0.2820 - val_mean_absolute_error: 0.4292
# Epoch 97/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1493 - mean_absolute_error: 0.3074 - val_loss: 0.2869 - val_mean_absolute_error: 0.4301
# Epoch 98/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1483 - mean_absolute_error: 0.3071 - val_loss: 0.3000 - val_mean_absolute_error: 0.4358
# Epoch 99/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1479 - mean_absolute_error: 0.3024 - val_loss: 0.2980 - val_mean_absolute_error: 0.4337
# Epoch 100/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1476 - mean_absolute_error: 0.3040 - val_loss: 0.2915 - val_mean_absolute_error: 0.4342
# Epoch 101/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1465 - mean_absolute_error: 0.3029 - val_loss: 0.2889 - val_mean_absolute_error: 0.4259
# Epoch 102/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1416 - mean_absolute_error: 0.2974 - val_loss: 0.2838 - val_mean_absolute_error: 0.4252
# Epoch 103/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1423 - mean_absolute_error: 0.2987 - val_loss: 0.2763 - val_mean_absolute_error: 0.4233
# Epoch 104/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1394 - mean_absolute_error: 0.2979 - val_loss: 0.2824 - val_mean_absolute_error: 0.4258
# Epoch 105/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1381 - mean_absolute_error: 0.2938 - val_loss: 0.2906 - val_mean_absolute_error: 0.4281
# Epoch 106/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1373 - mean_absolute_error: 0.2895 - val_loss: 0.2934 - val_mean_absolute_error: 0.4245
# Epoch 107/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1323 - mean_absolute_error: 0.2852 - val_loss: 0.2935 - val_mean_absolute_error: 0.4285
# Epoch 108/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1343 - mean_absolute_error: 0.2911 - val_loss: 0.2843 - val_mean_absolute_error: 0.4237
# Epoch 109/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1324 - mean_absolute_error: 0.2866 - val_loss: 0.2795 - val_mean_absolute_error: 0.4194
# Epoch 110/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1315 - mean_absolute_error: 0.2861 - val_loss: 0.2768 - val_mean_absolute_error: 0.4175
# Epoch 111/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1312 - mean_absolute_error: 0.2894 - val_loss: 0.2910 - val_mean_absolute_error: 0.4205
# Epoch 112/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1318 - mean_absolute_error: 0.2818 - val_loss: 0.2839 - val_mean_absolute_error: 0.4213
# Epoch 113/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1292 - mean_absolute_error: 0.2839 - val_loss: 0.2782 - val_mean_absolute_error: 0.4207
# Epoch 114/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1281 - mean_absolute_error: 0.2799 - val_loss: 0.3103 - val_mean_absolute_error: 0.4313
# Epoch 115/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.1441 - mean_absolute_error: 0.3013 - val_loss: 0.3089 - val_mean_absolute_error: 0.4388
# Epoch 116/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1345 - mean_absolute_error: 0.2874 - val_loss: 0.3194 - val_mean_absolute_error: 0.4369
# Epoch 117/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1343 - mean_absolute_error: 0.2865 - val_loss: 0.2880 - val_mean_absolute_error: 0.4229
# Epoch 118/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1255 - mean_absolute_error: 0.2790 - val_loss: 0.2833 - val_mean_absolute_error: 0.4164
# Epoch 119/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1192 - mean_absolute_error: 0.2683 - val_loss: 0.2868 - val_mean_absolute_error: 0.4211
# Epoch 120/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1185 - mean_absolute_error: 0.2672 - val_loss: 0.2830 - val_mean_absolute_error: 0.4259
# Epoch 121/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1172 - mean_absolute_error: 0.2676 - val_loss: 0.2818 - val_mean_absolute_error: 0.4209
# Epoch 122/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.1136 - mean_absolute_error: 0.2658 - val_loss: 0.2821 - val_mean_absolute_error: 0.4247
# Epoch 123/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1141 - mean_absolute_error: 0.2662 - val_loss: 0.2831 - val_mean_absolute_error: 0.4236
# Epoch 124/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1119 - mean_absolute_error: 0.2640 - val_loss: 0.2757 - val_mean_absolute_error: 0.4161
# Epoch 125/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1150 - mean_absolute_error: 0.2695 - val_loss: 0.2868 - val_mean_absolute_error: 0.4214
# Epoch 126/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1130 - mean_absolute_error: 0.2618 - val_loss: 0.2814 - val_mean_absolute_error: 0.4174
# Epoch 127/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.1101 - mean_absolute_error: 0.2600 - val_loss: 0.2767 - val_mean_absolute_error: 0.4179
# Epoch 128/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1165 - mean_absolute_error: 0.2707 - val_loss: 0.2930 - val_mean_absolute_error: 0.4226
# Epoch 129/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1120 - mean_absolute_error: 0.2619 - val_loss: 0.2889 - val_mean_absolute_error: 0.4202
# Epoch 130/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1023 - mean_absolute_error: 0.2495 - val_loss: 0.2896 - val_mean_absolute_error: 0.4276
# Epoch 131/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.1061 - mean_absolute_error: 0.2553 - val_loss: 0.2821 - val_mean_absolute_error: 0.4245
# Epoch 132/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.1094 - mean_absolute_error: 0.2649 - val_loss: 0.2892 - val_mean_absolute_error: 0.4183
# Epoch 133/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1078 - mean_absolute_error: 0.2584 - val_loss: 0.2841 - val_mean_absolute_error: 0.4268
# Epoch 134/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.1133 - mean_absolute_error: 0.2681 - val_loss: 0.2782 - val_mean_absolute_error: 0.4232
# Epoch 135/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.1002 - mean_absolute_error: 0.2490 - val_loss: 0.2863 - val_mean_absolute_error: 0.4193
# Epoch 136/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0976 - mean_absolute_error: 0.2414 - val_loss: 0.2800 - val_mean_absolute_error: 0.4180
# Epoch 137/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0961 - mean_absolute_error: 0.2415 - val_loss: 0.2914 - val_mean_absolute_error: 0.4176
# Epoch 138/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0969 - mean_absolute_error: 0.2423 - val_loss: 0.2913 - val_mean_absolute_error: 0.4319
# Epoch 139/150
# 9/9 [==============================] - 0s 14ms/step - loss: 0.0971 - mean_absolute_error: 0.2393 - val_loss: 0.2991 - val_mean_absolute_error: 0.4349
# Epoch 140/150
# 9/9 [==============================] - 0s 17ms/step - loss: 0.0962 - mean_absolute_error: 0.2453 - val_loss: 0.2872 - val_mean_absolute_error: 0.4320
# Epoch 141/150
# 9/9 [==============================] - 0s 16ms/step - loss: 0.0903 - mean_absolute_error: 0.2352 - val_loss: 0.2922 - val_mean_absolute_error: 0.4252
# Epoch 142/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0999 - mean_absolute_error: 0.2476 - val_loss: 0.3030 - val_mean_absolute_error: 0.4249
# Epoch 143/150
# 9/9 [==============================] - 0s 11ms/step - loss: 0.0915 - mean_absolute_error: 0.2381 - val_loss: 0.2840 - val_mean_absolute_error: 0.4243
# Epoch 144/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0880 - mean_absolute_error: 0.2318 - val_loss: 0.2930 - val_mean_absolute_error: 0.4326
# Epoch 145/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0875 - mean_absolute_error: 0.2280 - val_loss: 0.2911 - val_mean_absolute_error: 0.4257
# Epoch 146/150
# 9/9 [==============================] - 0s 12ms/step - loss: 0.0944 - mean_absolute_error: 0.2428 - val_loss: 0.2939 - val_mean_absolute_error: 0.4290
# Epoch 147/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0877 - mean_absolute_error: 0.2307 - val_loss: 0.3051 - val_mean_absolute_error: 0.4309
# Epoch 148/150
# 9/9 [==============================] - 0s 10ms/step - loss: 0.0840 - mean_absolute_error: 0.2269 - val_loss: 0.2918 - val_mean_absolute_error: 0.4264
# Epoch 149/150
# 9/9 [==============================] - 0s 13ms/step - loss: 0.0804 - mean_absolute_error: 0.2174 - val_loss: 0.3034 - val_mean_absolute_error: 0.4317
# Epoch 150/150
# 9/9 [==============================] - 0s 15ms/step - loss: 0.0836 - mean_absolute_error: 0.2223 - val_loss: 0.3025 - val_mean_absolute_error: 0.4273

# %% [markdown]
# ### Evaluate accuracy and loss of your model. This is how your plots should look like:
# <table><tr>
# <td> <img src="images/accuracy.png" style="width: 500px;"/> </td>
# <td> <img src="images/loss.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Summarize history for accuracy
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %%
# Summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

# %% [markdown]
# ### Now evaluate the predictions of your model in terms of RMSE and NRMSE. You should obtain plots like these:
# <table><tr>
# <td> <img src="images/inference.png" style="width: 500px;"/> </td>
# <td> <img src="images/inference_diff.png" style="width: 500px;"/> </td>
# </tr></table>

# %%
# Prediction
pred = model.predict(X_test).reshape(1,-1)[0]

rmse = RMSE(y_test, pred)
nrmse = NRMSE(y_test, pred)


print("rmse : ",rmse,"  nrmse : ",nrmse)
# Out:
# 4/4 [==============================] - 0s 4ms/step
# rmse :  0.7612503129554049   nrmse :  0.37695406581075036

# %%
my_x=np.arange(0,len(X_test[:,0]),1)

fig = plt.figure(figsize=(20,10))
plt.scatter(my_x, y_test, label='Real', color='blue', marker='o')
plt.scatter(my_x, pred, label='Inference', color='red', marker='s')
plt.title(f'Inference of log(NO2)  rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('log(NO2)')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(20,10))
my_d = abs(y_test-pred)

plt.bar(my_x,my_d)
plt.title(f'Inference of log(NO2) -- absolute difference between inference and ground truth rmse: {rmse:.3f}, nrmse: {nrmse:.3f}')
plt.ylabel('absolute value of difference in inference [log(NO2)]')
plt.xlabel('readings (rows of file)')
plt.grid()
plt.show()
